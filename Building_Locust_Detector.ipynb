# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 60.6 MB/s eta 0:00:00
# ...

# %%
# !pip install folium

# %%
# !pip install streamlit-folium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.2/529.2 kB 9.6 MB/s eta 0:00:00
# ...

# %%
# !pip install ngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 37.7 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
import json

# %%
import pandas
import matplotlib.pyplot

# %%
import streamlit
streamlit.set_page_config(page_title="Locust Breeding Site Detector", page_icon="🦗")
# Out:
# 2026-04-16 08:36:26.363 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
streamlit.title("🦗 Locust Breeding Site Detector")
# Out:
# 2026-04-16 08:36:26.371 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.516
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-04-16 08:36:26.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
streamlit.write("Upload your dataset to vizualize potential breeding sites on a map")
# Out:
# 2026-04-16 08:36:26.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
Locust_Datasets = streamlit.file_uploader("Upload your dataset", type="json")
# Out:
# 2026-04-16 08:36:26.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 08:36:26.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#Plotting the areas

from os.path import exists
if Locust_Datasets:
    data = json.load(Locust_Datasets)
    dataframes = pandas.DataFrame(data)
    dataframes["Locust_risk"] = dataframes["risk"].map({"yes": 1, "no": 0})

    streamlit.subheader("Breeding Site Map")
    map_centre = [dataframes["lat"].mean(), dataframes["lng"].mean()]

# %%
app_content = '''
import streamlit
import pandas
import json

# Folium = map

import folium
from streamlit_folium import streamlit_folium

streamlit.set_page_config(page_title="Locust Breeding Site Detector", page_icon="🦗", layout="wide")

streamlit.title("🦗 Locust Breeding Site Detector")
streamlit.write("Upload your dataset to visualize potential breeding sites on a map.")

Locust_Datasets = streamlit.file_uploader("Upload your dataset", type="json")

if Locust_Datasets:
    data = json.load(Locust_Datasets)
    dataframes = pandas.DataFrame(data)
    dataframes["Locust_risk"] = dataframes["risk"].map({"yes": 1, "no": 0})

    streamlit.subheader("Breeding Site Map")

    # Calculate central point of map
    map_center = [dataframes["lat"].mean(), dataframes["lng"].mean()]

    # Create a map using Folium which centers at the average coordinates for ease of access
    m = folium.Map(location=map_center, zoom_start=6)

    # Add markers for each data point
    for idx, row in dataframes.iterrows():
        popup_html = f"<b>Risk:</b> {row['risk']}<br><b>Location:</b> {row['lat']}, {row['lng']}"
        icon_color = 'red' if row['risk'] == 'yes' else 'green'
        folium.Marker(
            location=[row['lat'], row['lng']],
            popup=popup_html,
            icon=folium.Icon(color=icon_color, icon='info-sign')
        ).add_to(m)

    # Displaying the map in Streamlit
    streamlit_folium(m, width=700, height=500)

    streamlit.subheader("Risk Distribution")
    risk_counts = dataframes['risk'].value_counts().reset_index()
    risk_counts.columns = ['Risk', 'Count']
    streamlit.bar_chart(risk_counts.set_index('Risk'))

    streamlit.subheader("Raw Data")
    streamlit.dataframe

'''

with open("app.py", "w") as f:
    f.write(app_content)

print("app created successfully!")
# Out:
# app created successfully!

# %%
# !pip install pyngrok

from pyngrok import ngrok
from google.colab import userdata

# Retrieve ngrok token from userdata.get
NGROK_AUTH_TOKEN = userdata.get('ngrok_token')

ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Start a Streamlit app in the background
get_ipython().system_raw('streamlit run app.py --server.port 8501 --server.enableCORS false &')

# Open an ngrok tunnel to the Streamlit app
public_url = ngrok.connect(addr=8501, proto="http")
print(f"✅ Your app is live at: {public_url}")
print("\nMake sure to upload a JSON file with 'lat', 'lng', and 'risk' (yes/no) fields to see the map.")
# Out:
# ...
# ✅ Your app is live at: NgrokTunnel: "https://derick-multiarticulate-maisha.ngrok-free.dev" -> "http://localhost:8501"
#
# Make sure to upload a JSON file with 'lat', 'lng', and 'risk' (yes/no) fields to see the map.

# %%
from google.colab import files
req = '''streamlit
folium
streamlit-folium
pandas
matplotlib
'''

write = open('requirements.txt', 'w')
write.write(req)
write.close()
files.download('requirements.txt')
